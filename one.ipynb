# %%
# !pip install roboflow
# Out:
# Collecting roboflow
#   Using cached roboflow-1.2.11-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (2025.10.5)
# Collecting idna==3.7 (from roboflow)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (3.10.6)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (1.24.3)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (10.0.1)
# Collecting pi-heif<2 (from roboflow)
#   Using cached pi_heif-1.1.1-cp310-cp310-win_amd64.whl.metadata (6.7 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Using cached pillow_avif_plugin-1.5.2-cp310-cp310-win_amd64.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (6.0.2)
# Collecting requests-toolbelt (from roboflow)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting Pillow>=7.1.2 (from roboflow)
#   Using cached pillow-12.0.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: colorama in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->roboflow) (4.60.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->roboflow) (3.2.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages (from requests->roboflow) (3.4.3)
# Using cached roboflow-1.2.11-py3-none-any.whl (89 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Using cached pi_heif-1.1.1-cp310-cp310-win_amd64.whl (1.9 MB)
# Using cached pillow_avif_plugin-1.5.2-cp310-cp310-win_amd64.whl (9.9 MB)
# Using cached pillow-12.0.0-cp310-cp310-win_amd64.whl (7.0 MB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: pillow-avif-plugin, filetype, Pillow, opencv-python-headless, idna, pi-heif, requests-toolbelt, roboflow
#
#    ----- ---------------------------------- 1/8 [filetype]
#    ----- ---------------------------------- 1/8 [filetype]
#   Attempting uninstall: Pillow
#    ----- ---------------------------------- 1/8 [filetype]
#     Found existing installation: pillow 10.0.1
#    ----- ---------------------------------- 1/8 [filetype]
#     Can't uninstall 'pillow'. No files were found to uninstall.
#    ----- ---------------------------------- 1/8 [filetype]
#    ---------- ----------------------------- 2/8 [Pillow]
# WARNING: Ignoring invalid distribution -orch (c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Error parsing dependencies of pillow: [Errno 2] No such file or directory: 'c:\\users\\swaya\\appdata\\local\\programs\\python\\python310\\lib\\site-packages\\Pillow-10.0.1.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -orch (c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages)
#     WARNING: No metadata found in c:\users\swaya\appdata\local\programs\python\python310\lib\site-packages
#   ERROR: Can't roll back pillow; was not uninstalled
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\swaya\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\PIL\\QoiImagePlugin.py'
# Consider using the `--user` option or check the permissions.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="qpED5X6YWuhra522ggB1")
project = rf.workspace("supercell").project("birds-drons-pdile")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Birds&Drons-1 to yolov8:: 100%|██████████| 45775/45775 [01:06<00:00, 686.77it/s]
# Extracting Dataset Version Zip to Birds&Drons-1 in yolov8:: 100%|██████████| 2944/2944 [00:01<00:00, 2353.56it/s]
